# %% [markdown]
# ## Load the Data

# %%
import pandas as pd
import numpy as np
import os
from langchain.document_loaders import PyPDFLoader, UnstructuredPDFLoader, PyPDFium2Loader
from langchain.document_loaders import PyPDFDirectoryLoader, DirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from pathlib import Path
import random

## Input data directory
data_dir = "jpetstore"
inputdirectory = Path(f"./data_input/{data_dir}")
## This is where the output csv files will be written
out_dir = data_dir
outputdirectory = Path(f"./data_output/{out_dir}")

# %% [markdown]
# ## Create Pages

# %%
## Dir PDF Loader
# loader = PyPDFDirectoryLoader(inputdirectory)
## File Loader
# loader = PyPDFLoader("./data/MedicalDocuments/orf-path_health-n1.pdf")
loader = DirectoryLoader(inputdirectory, show_progress=True)
documents = loader.load()

splitter = RecursiveCharacterTextSplitter(
    chunk_size=1500,
    chunk_overlap=150,
    length_function=len,
    is_separator_regex=False,
)

pages = splitter.split_documents(documents)
print("Number of pages = ", len(pages))
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:02<00:00,  2.69s/it]
# Number of pages =  57

# %% [markdown]
# ## Create a dataframe of all the pages

# %%
from helpers.df_helpers import documents2Dataframe
df = documents2Dataframe(pages)
print(df.shape)
df.head()
# Out:
# (57, 3)
#                                                 text  \
# 0  Found 57 source code files: ../jpetstore/src/W...
# 1  return address2;\n\n}\n\npublic void setAddres...
# 2  ../jpetstore/src/WEB\n\nINF/classes/com/ibatis...
# 3  public void setQuantityByItemId(String itemId,...
# 4  }\n\npublic void setCategoryId(String category...
#
#                                source                          chunk_id
# 0  data_input/jpetstore/jpetstore.txt  f0a53e80a16644a8bb429157dd336adc
# 1  data_input/jpetstore/jpetstore.txt  27da81d187e14be398e34cc28f90cd0d
# 2  data_input/jpetstore/jpetstore.txt  031bed0aea024e1a97917d1cba57994e
# 3  data_input/jpetstore/jpetstore.txt  96fd3b1d7da24168992fa71cf364d4be
# 4  data_input/jpetstore/jpetstore.txt  844e66ec40364951b1e1b3e09bf8afa7

# %% [markdown]
# ## Extract Concepts

# %%
## This function uses the helpers/prompt function to extract concepts from text
from helpers.df_helpers import df2Graph
from helpers.df_helpers import graph2Df

# %% [markdown]
# If regenerate is set to True then the dataframes are regenerated and Both the dataframes are written in the csv format so we dont have to calculate them again.
#
#         dfne = dataframe of edges
#
#         df = dataframe of chunks
#
#
# Else the dataframes are read from the output directory

# %%
#create chunks
#df.to_csv(outputdirectory/"chunks.csv", sep="|", index=False)
# chunk size is the number of rows
chunksize=32
list_df = [df[i:i+chunksize] for i in range(0,len(df),chunksize)]
print(len(list_df))

##Test forloop filename
for i in range(len(list_df)):
    graph_file = "graph_" + str(i) + ".csv"
    #print(graph_file)
    outputfile = Path(f"./data_output/{out_dir}/{graph_file}")

    
   # print(outputfile)
# Out:
# 2

# %% [markdown]
# Generate New Knowledge Graph
# =====================

# %%
##create chunks
#df.to_csv(outputdirectory/"chunks.csv", sep="|", index=False)
# chunk size is the number of rows
chunksize=32
list_df = [df[i:i+chunksize] for i in range(0,len(df),chunksize)]
print(len(list_df))
for i in range(len(list_df)):
#for i in range(51,53):
    df = list_df[i]
    graph_file = "graph_" + str(i) + ".csv"
    chunks_file = "chunks_" + str(i) + ".csv"
    outputfile_graph = Path(f"./data_output/{out_dir}/{graph_file}")
    outputfile_chunks = Path(f"./data_output/{out_dir}/{chunks_file}")

    #print(len(df))
    concepts_list = df2Graph(df, model='zephyr:latest')
    dfg1 = graph2Df(concepts_list)
    if not os.path.exists(outputdirectory):
        os.makedirs(outputdirectory)
    
    dfg1.to_csv(outputfile_graph, sep="|", index=False)
    df.to_csv(outputfile_chunks,sep="|", index=False)
    dfg1.to_csv(outputdirectory/"graph.csv", mode='a', sep="|", index=False)
    df.to_csv(outputdirectory/"chunks.csv", mode='a',sep="|", index=False)

dfg1.replace("", np.nan, inplace=True)
dfg1.dropna(subset=["node_1", "node_2", 'edge'], inplace=True)
dfg1['count'] = 4 
## Increasing the weight of the relation to 4. 
## We will assign the weight of 1 when later the contextual proximity will be calculated.  
print(dfg1.shape)
dfg1.head()
# Out:
# 2
# [
#    {
#        "node_1": "Account",
#        "node_2": "userId",
#        "edge": "String userId; represents the unique identifier for a user in this application's domain."
#    },
#    {
#        "node_1": "Account",
#        "node_2": "email",
#        "edge": "String email; holds the registered email address of the user."
#    },
#    {
#        "node_1": "Account",
#        "node_2": "firstName",
#        "edge": "String firstName; stores the given name of the user."
#    },
#    {
#        "node_1": "Account",
#        "node_2": "lastName",
#        "edge": "String lastName; contains the family name or surname of the user."
#    },
#    {
#        "node_1": "Account",
#        "node_2": "status",
#        "edge": "String status; indicates the current state or condition of the user's account in this system."
#    },
#    {
#        "node_1": "Account",
#        "node_2": "address1",
#        "edge": "String address1; holds the primary street address or house number of the user's residence."
#    },
#    {
#        "node_1": "Account",
#        "node_2": "address2",
#        "edge": "String address2; stores any additional or secondary address information for the user's address."
#    },
#    {
#        "node_1": "Account",
#        "node_2": "city",
#        "edge": "String city; denotes the name of the town, city, or village where the user resides."
#    },
#    {
#        "node_1": "Account",
#        "node_2": "state",
#        "edge": "String state; specifies the abbreviated or full name of the province, state, or region in which the user's residence is located."
#    },
#    {
#        "node_1": "Account",
#        "node_2": "zip",
#        "edge": "String zip; holds the postal code, ZIP code, or pin code of the user's address."
#    },
#    {
#        "node_1": "Account",
#        "node_2": "country",
#        "edge": "String country; indicates the name or code for the nation or country in which the user's residence is situated."
#    },
#    {
#        "node_1": "Account",
#        "node_2": "phone",
#        "edge": "String phone; saves the user's contact number or telephone number."
#    },
#    {
#        "node_1": "Account",
#        "node_2": "favouriteCategoryId",
#        "edge": "String favouriteCategoryId; denotes the unique identifier for the preferred product category of the user."
#    },
#    {
#        "node_1": "Account",
#        "node_2": "languagePreference",
#        "edge": "String languagePreference; specifies the user's chosen or preferred language for interacting with this application."
#    },
#    {
#        "node_1": "Account",
#        "node_2": "listOption",
#        "edge": "boolean listOption; determines whether the user has opted to receive email lists or promotional emails from this system."
#    },
#    {
#        "node_1": "Account",
#        "node_2": "bannerOption",
#        "edge": "boolean bannerOption; indicates whether the user has selected to view or hide graphical advertisements or banners on this platform."
#    },
#    {
#        "node_1": "Account",
#        "node_2": "bannerName",
#        "edge": "String bannerName; holds the title, label, or description of a displayed banner or advertisement."
#    }
# ][
#   {
#     "node_1": "Cart",
#     "node_2": "WEB",
#     "edge": "is a part of or is related to"
#   },
#   {
#     "node_1": "jpetstore",
#     "node_2": "Cart",
#     "edge": "belongs to"
#   },
#   {
#     "node_1": "com.ibatis.jpetstore.domain",
#     "node_2": "Cart",
#     "edge": "is a class within"
#   },
#   {
#     "node_1": "java",
#     "node_2": "Cart",
#     "edge": "is written in"
#   },
#   {
#     "node_1": "Cart",
#     "node_2": "domain",
#     "edge": "is a type of"
#   },
#   {
#     "node_1": "com.ibatis.jpetstore.domain",
#     "node_2": "Cart",
#     "edge": ""
#   },
#   {
#     "node_1": "src",
#     "node_2": "/WEB/INF/classes/com/ibatis/jpetstore/domain/Cart.java",
#     "edge": "is located in"
#   }
# ][
#    {
#       "node_1": "Cart",
#       "node_2": "itemMap",
#       "edge": "is a property of Cart, which is a HashMap called itemMap that contains CartItems as values."
#    },
#    {
#       "node_1": "itemMap",
#       "node_2": "item",
#       "edge": "Each key in the itemMap is an Item object, which represents an item in the cart."
#    },
#    {
#       "node_1": "itemMap",
#       "node_2": "CartItem",
#       "edge": "The value of each entry in the itemMap is a CartItem object, which contains information about a specific quantity of an Item."
#    },
#    {
#       "node_1": "CartItem",
#       "node_2": "Item",
#       "edge": "A CartItem object corresponds to a specific Item object and keeps track of its quantity in the cart."
#    },
#    {
#       "node_1": "itemMap",
#       "node_2": "HashMap",
#       "edge": "The itemMap property is implemented as a synchronizedMap wrapped around a HashMap for concurrency management."
#    },
#    {
#       "node_1": "itemMap",
#       "node_2": "Collection",
#       "edge": "The getCartItems() method returns an iterator over the values of the itemMap, which are all CartItem objects."
#    },
#    {
#       "node_1": "itemMap",
#       "node_2": "Iterator",
#       "edge": "The getNumberOfItems() method returns the size of the itemMap, i.e., the total number of items in the cart."
#    }
# ][
#    {
#       "node_1": "setQuantityByItemId",
#       "node_2": "itemId",
#       "edge": "is the identifier for a specific product in the cart."
#    },
#    {
#       "node_1": "CartItem",
#       "node_2": "itemMap",
#       "edge": "is a map that associates item identifiers with their corresponding CartItems."
#    },
#    {
#       "node_1": "getSubTotal",
#       "node_2": "subTotal",
#       "edge": "calculates the total price of all items in the cart by multiplying their quantities and list prices."
#    },
#    {
#       "node_1": "Item",
#       "node_2": "listPrice",
#       "edge": "is the retail price for a specific product."
#    },
#    {
#       "node_1": "CartItem",
#       "node_2": "item",
#       "edge": "is the product being purchased by the customer."
#    },
#    {
#       "node_1": "Category",
#       "node_2": "categoryId",
#       "edge": "is a unique identifier for a specific product category."
#    }
# ]
# Here's the output based on your context input:
#
# [
#   {
#     "node_1": "Item",
#     "node_2": "Product",
#     "edge": "An Item belongs to a specific Product."
#   },
#   {
#     "node_1": "itemId",
#     "node_2": "Item",
#     "edge": "The unique identifier for an Item."
#   },
#   {
#     "node_1": "productId",
#     "node_2": "Product",
#     "edge": "The unique identifier for the Product associated with an Item."
#   },
#   {
#     "node_1": "listPrice",
#     "node_2": "Item",
#     "edge": "The price at which an Item is sold by the supplier to the retailer."
#   },
#   {
#     "node_1": "unitCost",
#     "node_2": "Item",
#     "edge": "The cost of purchasing one unit of the Item from the supplier."
#   },
#   {
#     "node_1": "supplierId",
#     "node_2": "Item",
#     "edge": "The unique identifier for the Supplier from whom the Item is sourced."
#   },
#   {
#     "node_1": "status",
#     "node_2": "Item",
#     "edge": "The current status of the Item in the inventory system (e.g., 'active', 'discontinued')."
#   },
#   {
#     "node_1": "attribute1",
#     "node_2": "Item",
#     "edge": "Additional information or properties about the Item, such as color or size."
#   },
#   {
#     "node_1": "attribute2",
#     "node_2": "Item",
#     "edge": "Additional information or properties about the Item, such as style or material."
#   },
#   {
#     "node_1": "attribute3",
#     "node_2": "Item",
#     "edge": "Additional information or properties about the Item, such as weight or dimensions."
#   },
#   {
#     "node_1": "attribute4",
#     "node_2": "Item",
#     "edge": "Additional information or properties about the Item, such as warranty or guarantee."
#   },
#   {
#     "node_1": "attribute5",
#     "node_2": "Item",
#     "edge": "Additional information or properties about the Item, such as country of origin or certification."
#   }
# ]
#
# ERROR ### Here is the buggy response:  Here's the output based on your context input:
#
# [
#   {
#     "node_1": "Item",
#     "node_2": "Product",
#     "edge": "An Item belongs to a specific Product."
#   },
#   {
#     "node_1": "itemId",
#     "node_2": "Item",
#     "edge": "The unique identifier for an Item."
#   },
#   {
#     "node_1": "productId",
#     "node_2": "Product",
#     "edge": "The unique identifier for the Product associated with an Item."
#   },
#   {
#     "node_1": "listPrice",
#     "node_2": "Item",
#     "edge": "The price at which an Item is sold by the supplier to the retailer."
#   },
#   {
#     "node_1": "unitCost",
#     "node_2": "Item",
#     "edge": "The cost of purchasing one unit of the Item from the supplier."
#   },
#   {
#     "node_1": "supplierId",
#     "node_2": "Item",
#     "edge": "The unique identifier for the Supplier from whom the Item is sourced."
#   },
#   {
#     "node_1": "status",
#     "node_2": "Item",
#     "edge": "The current status of the Item in the inventory system (e.g., 'active', 'discontinued')."
#   },
#   {
#     "node_1": "attribute1",
#     "node_2": "Item",
#     "edge": "Additional information or properties about the Item, such as color or size."
#   },
#   {
#     "node_1": "attribute2",
#     "node_2": "Item",
#     "edge": "Additional information or properties about the Item, such as style or material."
#   },
#   {
#     "node_1": "attribute3",
#     "node_2": "Item",
#     "edge": "Additional information or properties about the Item, such as weight or dimensions."
#   },
#   {
#     "node_1": "attribute4",
#     "node_2": "Item",
#     "edge": "Additional information or properties about the Item, such as warranty or guarantee."
#   },
#   {
#     "node_1": "attribute5",
#     "node_2": "Item",
#     "edge": "Additional information or properties about the Item, such as country of origin or certification."
#   }
# ]
#
#
# [
#   {
#     "node_1": "getItemId",
#     "node_2": "toString",
#     "edge": "is a method in the given class"
#   },
#   {
#     "node_1": "productId",
#     "node_2": "getProductId",
#     "edge": "returns the value of the productId variable in the class"
#   },
#   {
#     "node_1": "supplierId",
#     "node_2": "getSupplierId",
#     "edge": "returns the value of the supplierId variable in the class"
#   },
#   {
#     "node_1": "listPrice",
#     "node_2": "getListPrice",
#     "edge": "returns the value of the listPrice variable in the class"
#   },
#   {
#     "node_1": "unitCost",
#     "node_2": "getUnitCost",
#     "edge": "returns the value of the unitCost variable in the class"
#   },
#   {
#     "node_1": "status",
#     "node_2": "getStatus",
#     "edge": "returns the value of the status variable in the class"
#   },
#   {
#     "node_1": "attribute1",
#     "node_2": "getAttribute1",
#     "edge": "returns the value of the attribute1 variable in the class"
#   },
#   {
#     "node_1": "attribute2",
#     "node_2": "getAttribute2",
#     "edge": "returns the value of the attribute2 variable in the class"
#   },
#   {
#     "node_1": "attribute3",
#     "node_2": "getAttribute3",
#     "edge": "returns the value of the attribute3 variable in the class"
#   },
#   {
#     "node_1": "attribute4",
#     "node_2": "getAttribute4",
#     "edge": "returns the value of the attribute4 variable in the class"
#   },
#   {
#     "node_1": "attribute5",
#     "node_2": "getAttribute5",
#     "edge": "returns the value of the attribute5 variable in the class"
#   }
# ][
#    {
#       "node_1": "LineItem",
#       "node_2": "Item",
#       "edge": "In the context provided, 'LineItem' is a class that contains information about an item in an order. It has a reference to the 'Item' object, which contains details such as itemId and listPrice."
#    },
#    {
#       "node_1": "orderId",
#       "node_2": "LineItem",
#       "edge": "The 'orderId' is an integer that identifies a specific order in the system. It is associated with the 'LineItem' class, which keeps track of items for that particular order."
#    },
#    {
#       "node_1": "lineNumber",
#       "node_2": "LineItem",
#       "edge": "The 'lineNumber' is an integer that specifies the position of a particular item within its corresponding order. It belongs to the 'LineItem' class."
#    },
#    {
#       "node_1": "itemId",
#       "node_2": "String",
#       "edge": "The 'itemId' is a string that uniquely identifies an item in the system. It is part of both the 'Item' and 'LineItem' classes."
#    },
#    {
#       "node_1": "quantity",
#       "node_2": "int",
#       "edge": "The 'quantity' is a number that represents how many of a particular item have been ordered. It belongs to the 'LineItem' class."
#    },
#    {
#       "node_1": "unitprice",
#       "node_2": "BigDecimal",
#       "edge": "The 'unitPrice' is a monetary value that represents the price of a single unit of an item. It is part of both the 'Item' and 'LineItem' classes, but is stored as a 'BigDecimal' in 'LineItem' due to its decimal nature."
#    }
# ]
# [
#    {
#        "node_1": "Order",
#        "node_2": "orderId",
#        "edge": "Order has an integer identifier called orderId"
#    },
#    {
#        "node_1": "Order",
#        "node_2": "userId",
#        "edge": "Order is associated with a user identified by userId"
#    },
#    {
#        "node_1": "Order",
#        "node_2": "orderDate",
#        "edge": "Order has a date called orderDate"
#    },
#    {
#        "node_1": "Order.shipAddress1",
#        "node_2": "Order",
#        "edge": "Shipping address line 1 is associated with the Order object"
#    },
#    {
#        "node_1": "Order.shipAddress2",
#        "node_2": "Order",
#        "edge": "Shipping address line 2 is associated with the Order object"
#    },
#    {
#        "node_1": "Order.shipCity",
#        "node_2": "Order",
#        "edge": "Shipping city is associated with the Order object"
#    },
#    {
#        "node_1": "Order.shipState",
#        "node_2": "Order",
#        "edge": "Shipping state is associated with the Order object"
#    },
#    {
#        "node_1": "Order.shipZip",
#        "node_2": "Order",
#        "edge": "Shipping zip code is associated with the Order object"
#    },
#    {
#        "node_1": "Order.shipCountry",
#        "node_2": "Order",
#        "edge": "Shipping country is associated with the Order object"
#    },
#    {
#        "node_1": "Order.billAddress1",
#        "node_2": "Order",
#        "edge": "Billing address line 1 is associated with the Order object"
#    },
#    {
#        "node_1": "Order.billAddress2",
#        "node_2": "Order",
#        "edge": "Billing address line 2 is associated with the Order object"
#    },
#    {
#        "node_1": "Order.billCity",
#        "node_2": "Order",
#        "edge": "Billing city is associated with the Order object"
#    },
#    {
#        "node_1": "Order.billState",
#        "node_2": "Order",
#        "edge": "Billing state is associated with the Order object"
#    },
#    {
#        "node_1": "Order.billZip",
#        "node_2": "Order",
#        "edge": "Billing zip code is associated with the Order object"
#    },
#    {
#        "node_1": "Order.billCountry",
#        "node_2": "Order",
#        "edge": "Billing country is associated with the Order object"
#    },
#    {
#        "node_1": "Account",
#        "node_2": "userId",
#        "edge": "User's identifier in the system is userId"
#    },
#    {
#        "node_1": "Account",
#        "node_2": "firstName",
#        "edge": "User's first name is firstName"
#    },
#    {
#        "node_1": "Account.lastName",
#        "node_2": "Account",
#        "edge": "User's last name is associated with the Account object"
#    },
#    {
#        "node_1": "Account.address1",
#        "node_2": "Account",
#        "edge": "User's billing/shipping address line 1 is associated with the Account object"
#    },
#    {
#        "node_1": "Account.address2",
#        "node_2": "Account",
#        "edge": "User's billing/shipping address line 2 is associated with the Account object"
#    },
#    {
#        "node_1": "Account.city",
#        "node_2": "Account",
#        "edge": "User's city is associated with the Account object"
#    },
#    {
#        "node_1": "Account.state",
#        "node_2": "Account",
#        "edge": "User's state is associated with the Account object"
#    },
#    {
#        "node_1": "Account.zip",
#        "node_2": "Account",
#        "edge": "User's zip code is associated with the Account object"
#    },
#    {
#        "node_1": "Account.country",
#        "node_2": "Account",
#        "edge": "User's country is associated with the Account object"
#    },
#    {
#        "node_1": "Cart.itemList",
#        "node_2": "Cart",
#        "edge": "Cart's item list is stored in itemList"
#    },
#    {
#        "node_1": "BigDecimal",
#        "node_2": "unitPrice",
#        "edge": "Unit price of an order item is represented by BigDecimal type"
#    }
# ][
#    {
#       "node_1": "orderId",
#       "node_2": "getOrderId",
#       "edge": "method to retrieve the unique order identifier"
#    },
#    {
#       "node_1": "userId",
#       "node_2": "getUserId",
#       "edge": "method to retrieve the user's account ID"
#    },
#    {
#       "node_1": "orderDate",
#       "node_2": "getOrderDate",
#       "edge": "method to retrieve the date when the order was placed"
#    },
#    {
#       "node_1": "shipAddress1",
#       "node_2": "shipAddress1",
#       "edge": "address where the product will be shipped"
#    },
#    {
#       "node_1": "cart",
#       "node_2": "getCartItems",
#       "edge": "list of products in the customer's shopping cart"
#    },
#    {
#       "node_1": "orderId",
#       "node_2": "lineItem.setOrderId(int)",
#       "edge": "relationship between a line item and the corresponding order"
#    },
#    {
#       "node_1": "lineItems",
#       "node_2": "getLineItems()",
#       "edge": "list of line items for an order"
#    },
#    {
#       "node_1": "lineItem",
#       "node_2": "lineItem(int, int, CartItem)",
#       "edge": "constructor to create a new line item object"
#    },
#    {
#       "node_1": "lineItem",
#       "node_2": "getOrderId()",
#       "edge": "method to retrieve the order ID associated with the current line item"
#    },
#    {
#       "node_1": "lineItem",
#       "node_2": "setOrderId(int)",
#       "edge": "method to set the order ID for the current line item"
#    },
#    {
#       "node_1": "cartItem",
#       "node_2": "addLineItem(CartItem)",
#       "edge": "method to add a cart item to the list of line items for an order"
#    },
#    {
#       "node_1": "orderId",
#       "node_2": "lineItem.getOrderId()",
#       "edge": "relationship between an order and its corresponding line items"
#    },
#    {
#       "node_1": "shipAddress1",
#       "node_2": "billToFirstName + ' ' + billToLastName",
#       "edge": "the address where the product will be shipped is the same as the billing address for this customer"
#    },
#    {
#       "node_1": "shipAddress1",
#       "node_2": "account.getAddress1()",
#       "edge": "relationship between the shipping address and the account information for this customer"
#    },
#    {
#       "node_1": "billAddress1",
#       "node_2": "account.getAddress1()",
#       "edge": "the billing address is stored in the customer's account information"
#    },
#    {
#       "node_1": "shipCity",
#       "node_2": "account.getCity()",
#       "edge": "relationship between the shipping address and the account information for this customer"
#    },
#    {
#       "node_1": "billCity",
#       "node_2": "account.getCity()",
#       "edge": "the billing address is stored in the customer's account information"
#    },
#    {
#       "node_1": "shipState",
#       "node_2": "account.getState()",
#       "edge": "relationship between the shipping address and the account information for this customer"
#    },
#    {
#       "node_1": "billState",
#       "node_2": "account.getState()",
#       "edge": "the billing address is stored in the customer's account information"
#    },
#    {
#       "node_1": "shipZip",
#       "node_2": "account.getZip()",
#       "edge": "relationship between the shipping address and the account information for this customer"
#    },
#    {
#       "node_1": "billZip",
#       "node_2": "account.getZip()",
#       "edge": "the billing address is stored in the customer's account information"
#    },
#    {
#       "node_1": "shipCountry",
#       "node_2": "account.getCountry()",
#       "edge": "relationship between the shipping address and the account information for this customer"
#    },
#    {
#       "node_1": "billCountry",
#       "node_2": "account.getCountry()",
#       "edge": "the billing address is stored in the customer's account information"
#    },
#    {
#       "node_1": "totalPrice",
#       "node_2": "cart.getSubTotal()",
#       "edge": "relationship between the total price of an order and the contents of the shopping cart"
#    }
# ][
#    {
#        "node_1": "getShipAddress1",
#        "node_2": "shipAddress1",
#        "edge": "method 'getShipAddress1' returns the value of the 'shipAddress1' variable"
#    },
#    {
#        "node_1": "shipAddress1",
#        "node_2": "String",
#        "edge": "data type of 'shipAddress1' is String"
#    },
#    {
#        "node_1": "getShipAddress2",
#        "node_2": "shipAddress2",
#        "edge": "method 'getShipAddress2' returns the value of the 'shipAddress2' variable"
#    },
#    {
#        "node_1": "shipAddress2",
#        "node_2": "String",
#        "edge": "data type of 'shipAddress2' is String"
#    },
#    {
#        "node_1": "getShipCity",
#        "node_2": "shipCity",
#        "edge": "method 'getShipCity' returns the value of the 'shipCity' variable"
#    },
#    {
#        "node_1": "shipCity",
#        "node_2": "String",
#        "edge": "data type of 'shipCity' is String"
#    },
#    {
#        "node_1": "getShipState",
#        "node_2": "shipState",
#        "edge": "method 'getShipState' returns the value of the 'shipState' variable"
#    },
#    {
#        "node_1": "shipState",
#        "node_2": "String",
#        "edge": "data type of 'shipState' is String"
#    },
#    {
#        "node_1": "getShipZip",
#        "node_2": "shipZip",
#        "edge": "method 'getShipZip' returns the value of the 'shipZip' variable"
#    },
#    {
#        "node_1": "shipZip",
#        "node_2": "String",
#        "edge": "data type of 'shipZip' is String"
#    },
#    {
#        "node_1": "getShipCountry",
#        "node_2": "shipCountry",
#        "edge": "method 'getShipCountry' returns the value of the 'shipCountry' variable"
#    },
#    {
#        "node_1": "shipCountry",
#        "node_2": "String",
#        "edge": "data type of 'shipCountry' is String"
#    },
#    {
#        "node_1": "getBillAddress1",
#        "node_2": "billAddress1",
#        "edge": "method 'getBillAddress1' returns the value of the 'billAddress1' variable"
#    },
#    {
#        "node_1": "billAddress1",
#        "node_2": "String",
#        "edge": "data type of 'billAddress1' is String"
#    },
#    {
#        "node_1": "getBillAddress2",
#        "node_2": "billAddress2",
#        "edge": "method 'getBillAddress2' returns the value of the 'billAddress2' variable"
#    },
#    {
#        "node_1": "billAddress2",
#        "node_2": "String",
#        "edge": "data type of 'billAddress2' is String"
#    },
#    {
#        "node_1": "getBillCity",
#        "node_2": "billCity",
#        "edge": "method 'getBillCity' returns the value of the 'billCity' variable"
#    },
#    {
#        "node_1": "billCity",
#        "node_2": "String",
#        "edge": "data type of 'billCity' is String"
#    },
#    {
#        "node_1": "getBillState",
#        "node_2": "billState",
#        "edge": "method 'getBillState' returns the value of the 'billState' variable"
#    },
#    {
#        "node_1": "billState",
#        "node_2": "String",
#        "edge": "data type of 'billState' is String"
#    },
#    {
#        "node_1": "getBillZip",
#        "node_2": "billZip",
#        "edge": "method 'getBillZip' returns the value of the 'billZip' variable"
#    },
#    {
#        "node_1": "billZip",
#        "node_2": "String",
#        "edge": "data type of 'billZip' is String"
#    }
# ][
#    {
#        "node_1": "getTotalPrice",
#        "node_2": "totalPrice",
#        "edge": "is a method that returns the total price of the order.",
#    },
#    {
#        "node_1": "setTotalPrice",
#        "node_2": "totalPrice",
#        "edge": "is used to set the value of the total price variable.",
#    },
#    {
#        "node_1": "getBillZip",
#        "node_2": "billZip",
#        "edge": "is a method that retrieves the billing zip code.",
#    },
#    {
#        "node_1": "setBillZip",
#        "node_2": "billZip",
#        "edge": "is used to set the value of the billing zip code variable.",
#    },
#    {
#        "node_1": "getBillCountry",
#        "node_2": "billCountry",
#        "edge": "is a method that retrieves the billing country.",
#    },
#    {
#        "node_1": "setBillCountry",
#        "node_2": "billCountry",
#        "edge": "is used to set the value of the billing country variable.",
#    },
#    {
#        "node_1": "getCourier",
#        "node_2": "courier",
#        "edge": "is a method that returns the name of the courier service being used.",
#    },
#    {
#        "node_1": "setCourier",
#        "node_2": "courier",
#        "edge": "is used to set the value of the courier variable.",
#    },
#    {
#        "node_1": "getBillToFirstName",
#        "node_2": "billToFirstName",
#        "edge": "is a method that retrieves the billing recipient's first name.",
#    },
#    {
#        "node_1": "setBillToFirstName",
#        "node_2": "billToFirstName",
#        "edge": "is used to set the value of the billing recipient's first name variable.",
#    },
#    {
#        "node_1": "getBillToLastName",
#        "node_2": "billToLastName",
#        "edge": "is a method that retrieves the billing recipient's last name.",
#    },
#    {
#        "node_1": "setBillToLastName",
#        "node_2": "billToLastName",
#        "edge": "is used to set the value of the billing recipient's last name variable.",
#    },
#    {
#        "node_1": "getShipToFirstName",
#        "node_2": "shipToFirstName",
#        "edge": "is a method that retrieves the shipping recipient's first name.",
#    },
#    {
#        "node_1": "setShipToFirstName",
#        "node_2": "shipToFirstName",
#        "edge": "is used to set the value of the shipping recipient's first name variable.",
#    },
#    {
#        "node_1": "getShipToLastName",
#        "node_2": "shipToLastName",
#        "edge": "is a method that retrieves the shipping recipient's last name.",
#    },
#    {
#        "node_1": "setShipToLastName",
#        "node_2": "shipToLastName",
#        "edge": "is used to set the value of the shipping recipient's last name variable.",
#    },
#    {
#        "node_1": "getCreditCard",
#        "node_2": "creditCard",
#        "edge": "is a method that retrieves the name of the credit card being used.",
#    },
#    {
#        "node_1": "setCreditCard",
#        "node_2": "creditCard",
#        "edge": "is used to set the value of the credit card variable.",
#    },
#    {
#        "node_1": "getExpiryDate",
#        "node_2": "expiryDate",
#        "edge": "is a method that retrieves the expiration date of the credit card.",
#    },
#    {
#        "node_1": "setExpiryDate",
#        "node_2": "expiryDate",
#        "edge": "is used to set the value of the credit card's expiration date variable.",
#    }
# ]
#
# ERROR ### Here is the buggy response:  [
#    {
#        "node_1": "getTotalPrice",
#        "node_2": "totalPrice",
#        "edge": "is a method that returns the total price of the order.",
#    },
#    {
#        "node_1": "setTotalPrice",
#        "node_2": "totalPrice",
#        "edge": "is used to set the value of the total price variable.",
#    },
#    {
#        "node_1": "getBillZip",
#        "node_2": "billZip",
#        "edge": "is a method that retrieves the billing zip code.",
#    },
#    {
#        "node_1": "setBillZip",
#        "node_2": "billZip",
#        "edge": "is used to set the value of the billing zip code variable.",
#    },
#    {
#        "node_1": "getBillCountry",
#        "node_2": "billCountry",
#        "edge": "is a method that retrieves the billing country.",
#    },
#    {
#        "node_1": "setBillCountry",
#        "node_2": "billCountry",
#        "edge": "is used to set the value of the billing country variable.",
#    },
#    {
#        "node_1": "getCourier",
#        "node_2": "courier",
#        "edge": "is a method that returns the name of the courier service being used.",
#    },
#    {
#        "node_1": "setCourier",
#        "node_2": "courier",
#        "edge": "is used to set the value of the courier variable.",
#    },
#    {
#        "node_1": "getBillToFirstName",
#        "node_2": "billToFirstName",
#        "edge": "is a method that retrieves the billing recipient's first name.",
#    },
#    {
#        "node_1": "setBillToFirstName",
#        "node_2": "billToFirstName",
#        "edge": "is used to set the value of the billing recipient's first name variable.",
#    },
#    {
#        "node_1": "getBillToLastName",
#        "node_2": "billToLastName",
#        "edge": "is a method that retrieves the billing recipient's last name.",
#    },
#    {
#        "node_1": "setBillToLastName",
#        "node_2": "billToLastName",
#        "edge": "is used to set the value of the billing recipient's last name variable.",
#    },
#    {
#        "node_1": "getShipToFirstName",
#        "node_2": "shipToFirstName",
#        "edge": "is a method that retrieves the shipping recipient's first name.",
#    },
#    {
#        "node_1": "setShipToFirstName",
#        "node_2": "shipToFirstName",
#        "edge": "is used to set the value of the shipping recipient's first name variable.",
#    },
#    {
#        "node_1": "getShipToLastName",
#        "node_2": "shipToLastName",
#        "edge": "is a method that retrieves the shipping recipient's last name.",
#    },
#    {
#        "node_1": "setShipToLastName",
#        "node_2": "shipToLastName",
#        "edge": "is used to set the value of the shipping recipient's last name variable.",
#    },
#    {
#        "node_1": "getCreditCard",
#        "node_2": "creditCard",
#        "edge": "is a method that retrieves the name of the credit card being used.",
#    },
#    {
#        "node_1": "setCreditCard",
#        "node_2": "creditCard",
#        "edge": "is used to set the value of the credit card variable.",
#    },
#    {
#        "node_1": "getExpiryDate",
#        "node_2": "expiryDate",
#        "edge": "is a method that retrieves the expiration date of the credit card.",
#    },
#    {
#        "node_1": "setExpiryDate",
#        "node_2": "expiryDate",
#        "edge": "is used to set the value of the credit card's expiration date variable.",
#    }
# ]
#
#
# [
#   {
#     "node_1": "Product",
#     "node_2": "CategoryId",
#     "edge": "Relationship between a product and its category ID, often represented as a foreign key in a database."
#   },
#   {
#     "node_1": "Product",
#     "node_2": "Name",
#     "edge": "The name of the product is an essential characteristic of it."
#   },
#   {
#     "node_1": "Product",
#     "node_2": "Description",
#     "edge": "Additional information about a product that provides further details."
#   },
#   {
#     "node_1": "Product",
#     "node_2": "Image",
#     "edge": "A visual representation of the product, often used for marketing purposes."
#   },
#   {
#     "node_1": "ProductId",
#     "node_2": "CategoryId",
#     "edge": "The category ID that a particular product belongs to is necessary for its classification and organization within a database or inventory system."
#   }
# ][
#   {
#     "node_1": "AccountDao",
#     "node_2": "dao",
#     "edge": "AccountDao is a type of dao (data access object)"
#   },
#   {
#     "node_1": "AccountDao",
#     "node_2": "persistence",
#     "edge": "AccountDao belongs to the package com.ibatis.jpetstore.persistence"
#   },
#   {
#     "node_1": "com.ibatis.jpetstore.domain",
#     "node_2": "Account",
#     "edge": "Account is a class in the package com.ibatis.jpetstore.domain"
#   },
#   {
#     "node_1": "com.ibatis.jpetstore.domain",
#     "node_2": "Sequence",
#     "edge": "Sequence is a class in the package com.ibatis.jpetstore.domain"
#   },
#   {
#     "node_1": "com.ibatis.jpetstore.domain",
#     "node_2": "Signon",
#     "edge": "Signon is a class in the package com.ibatis.jpetstore.domain"
#   },
#   {
#     "node_1": "com.ibatis.jpetstore.domain",
#     "node_2": "Setter",
#     "edge": "Setter refers to methods with set prefix in classes of the package com.ibatis.jpetstore.domain"
#   },
#   {
#     "node_1": "com.ibatis.jpetstore.domain",
#     "node_2": "Getter",
#     "edge": "Getter refers to methods with get prefix in classes of the package com.ibatis.jpetstore.domain"
#   },
#   {
#     "node_1": "java.lang",
#     "node_2": "String",
#     "edge": "String is a data type used for storing and manipulating textual information in Java"
#   },
#   {
#     "node_1": "com.ibatis.jpetstore.domain",
#     "node_2": "Description",
#     "edge": "Description is a field of type String in the class Item in the package com.ibatis.jpetstore.domain"
#   }
# ][
#   {
#     "node_1": "Account",
#     "node_2": "Dao",
#     "edge": "is a type of DAO, used to access data in the database for an application."
#   },
#   {
#     "node_1": "AccountDao",
#     "node_2": "Account",
#     "edge": "operates on instances of Account to perform CRUD operations in the database."
#   },
#   {
#     "node_1": "AccountDao",
#     "node_2": "DaoTransaction",
#     "edge": "is used to manage transactions when accessing data from multiple DAOs within a single unit of work."
#   },
#   {
#     "node_1": "CategoryDao",
#     "node_2": "Category",
#     "edge": "operates on instances of Category to perform CRUD operations in the database."
#   },
#   {
#     "node_1": "CategoryDao",
#     "node_2": "DaoTransaction",
#     "edge": "is used to manage transactions when accessing data from multiple DAOs within a single unit of work."
#   },
#   {
#     "node_1": "InventoryDao",
#     "node_2": "Inventory",
#     "edge": "operates on instances of Inventory to perform CRUD operations in the database, updating inventory quantities."
#   }
# ][
#    {
#        "node_1": "ItemDao",
#        "node_2": "DaoTransaction",
#        "edge": "ItemDao is used to perform database operations on Item domain objects, and DaoTransaction is a context object through which transactional resources such as connections and statements can be accessed."
#    },
#    {
#        "node_1": "ItemDao",
#        "node_2": "String itemId",
#        "edge": "The method updateInventoryQuantity() in the ItemDao interface takes a String parameter representing the ID of an item."
#    },
#    {
#        "node_1": "ItemDao",
#        "node_2": "int quantity",
#        "edge": "The method updateInventoryQuantity() in the ItemDao interface also takes an integer parameter representing the new quantity of the item."
#    },
#    {
#        "node_1": "ItemDao",
#        "node_2": "DaoException",
#        "edge": "The methods getItem() and updateInventoryQuantity() in the ItemDao interface throw DaoException to indicate that a data access error occurred during their execution."
#    },
#    {
#        "node_1": "ItemDao",
#        "node_2": "com.ibatis.jpetstore.persistence.dao.Item",
#        "edge": "The getItem() method in the ItemDao interface returns an Item object representing a specific item."
#    },
#    {
#        "node_1": "ItemDao",
#        "node_2": "com.ibatis.jpetstore.persistence.dao.DaoTransaction",
#        "edge": "The getItem() method in the ItemDao interface takes a DaoTransaction object as its argument to provide database access resources."
#    },
#    {
#        "node_1": "ItemDao",
#        "node_2": "com.ibatis.db.dao.Dao",
#        "edge": "The ItemDao interface extends the abstract Dao class, which provides common functionality for data access in iBATIS."
#    },
#    {
#        "node_1": "ItemDao",
#        "node_2": "java.util.List",
#        "edge": "The getItemList() method in the ItemDao interface returns a List of all items."
#    },
#    {
#        "node_1": "ItemDao",
#        "node_2": "String productId",
#        "edge": "The getItemListByProduct() method in the ItemDao interface takes a String parameter representing the ID of a product and returns a List of items associated with that product."
#    },
#    {
#        "node_1": "LineItemDao",
#        "node_2": "DaoTransaction",
#        "edge": "The LineItemDao interface is used to perform database operations on LineItem domain objects, and DaoTransaction is a context object through which transactional resources such as connections and statements can be accessed."
#    },
#    {
#        "node_1": "LineItemDao",
#        "node_2": "LineItem",
#        "edge": "The insertLineItem() method in the LineItemDao interface adds a new LineItem object to the database."
#    },
#    {
#        "node_1": "LineItemDao",
#        "node_2": "int orderId",
#        "edge": "The getLineItemsByOrderId() method in the LineItemDao interface takes an integer parameter representing the ID of an order and returns a List of line items associated with that order."
#    },
#    {
#        "node_1": "LineItemDao",
#        "node_2": "com.ibatis.jpetstore.persistence.dao.DaoException",
#        "edge": "The methods insertLineItem() and getLineItemsByOrderId() in the LineItemDao interface throw DaoException to indicate that a data access error occurred during their execution."
#    },
#    {
#        "node_1": "LineItemDao",
#        "node_2": "com.ibatis.jpetstore.persistence.dao.DaoTransaction",
#        "edge": "The insertLineItem() method in the LineItemDao interface takes a DaoTransaction object as its argument to provide database access resources."
#    },
#    {
#        "node_1": "LineItemDao",
#        "node_2": "java.util.List",
#        "edge": "The getLineItemsByOrderId() method in the LineItemDao interface returns a List of line items associated with a specific order."
#    },
#    {
#        "node_1": "com.ibatis.jpetstore.persistence.dao.ItemDao",
#        "node_2": "com.ibatis.jpetstore.persistence.dao.LineItemDao",
#        "edge": "Both ItemDao and LineItemDao provide database access functionality for the JPetStore application."
#    }
# ]
# [
#    {
#        "node_1": "getLineItemsByOrderId",
#        "node_2": "OrderDao",
#        "edge": "is a method of the OrderDao interface which retrieves all line items associated with a specific order identified by the given order ID"
#    },
#    {
#        "node_1": "getOrder",
#        "node_2": "OrderDao",
#        "edge": "is a method of the OrderDao interface which retrieves detailed information about an order identified by the given order ID"
#    },
#    {
#        "node_1": "getOrdersByUserId",
#        "node_2": "OrderDao",
#        "edge": "is a method of the OrderDao interface which retrieves all orders associated with a specific user identified by the given username"
#    },
#    {
#        "node_1": "OrderDao",
#        "node_2": "DaoTransaction",
#        "edge": "is used as an argument in the methods of the OrderDao interface to provide a data access transaction context for database operations"
#    },
#    {
#        "node_1": "insertOrder",
#        "node_2": "OrderDao",
#        "edge": "is a method of the OrderDao interface which creates a new order in the database"
#    },
#    {
#                   "node_1": "getNextOrderId",
#                   "node_2": "OrderDao",
#                   "edge": "is a method of the OrderDao interface which returns the next available order ID to be assigned by the system for new orders"
#                },
#                {
#                    "node_1": "ProductDao",
#                    "node_2": "DaoTransaction",
#                    "edge": "is used as an argument in the methods of the ProductDao interface to provide a data access transaction context for database operations"
#                },
#                {
#                   "node_1": "getProduct",
#                   "node_2": "ProductDao",
#                   "edge": "is a method of the ProductDao interface which retrieves detailed information about a specific product identified by the given product ID"
#                },
#                {
#                    "node_1": "getProductList",
#                    "node_2": "ProductDao",
#                    "edge": "is a method of the ProductDao interface which retrieves a list of all products currently available in the system"
#                }
# ][
#   {
#     "node_1": "List",
#     "node_2": "getProductList",
#     "edge": "List is a collection of elements, and getProductList is a method in a class that returns a List containing product information."
#   },
#   {
#     "node_1": "DaoTransaction",
#     "node_2": "trans",
#     "edge": "DaoTransaction represents a database transaction and trans is a parameter passed to the methods to initiate the transaction."
#   },
#   {
#     "node_1": "List",
#     "node_2": "getProductListByCategory",
#     "edge": "List is a collection of elements, and getProductListByCategory is a method in a class that returns a List containing product information filtered by categoryId."
#   },
#   {
#     "node_1": "DaoTransaction",
#     "node_2": "trans",
#     "edge": "DaoTransaction represents a database transaction and trans is a parameter passed to the methods to initiate the transaction."
#   },
#   {
#     "node_1": "List",
#     "node_2": "getProductListByKeyword",
#     "edge": "List is a collection of elements, and getProductListByKeyword is a method in a class that returns a List containing product information filtered by keyword."
#   },
#   {
#     "node_1": "DaoTransaction",
#     "node_2": "trans",
#     "edge": "DaoTransaction represents a database transaction and trans is a parameter passed to the methods to initiate the transaction."
#   },
#   {
#     "node_1": "Signon",
#     "node_2": "getSignon",
#     "edge": "Signon is a class representing user authentication information, and getSignon is a method in a class that returns a Signon object based on provided username and password."
#   },
#   {
#     "node_1": "DaoTransaction",
#     "node_2": "trans",
#     "edge": "DaoTransaction represents a database transaction and trans is a parameter passed to the methods to initiate the transaction."
#   },
#   {
#     "node_1": "Signon",
#     "node_2": "signon",
#     "edge": "Signon is a class representing user authentication information, and signon is a variable name used in the updateSignon() method to pass an updated Signon object."
#   },
#   {
#     "node_1": "DaoTransaction",
#     "node_2": "trans",
#     "edge": "DaoTransaction represents a database transaction and trans is a parameter passed to the methods to initiate the transaction."
#   },
#   {
#     "node_1": "Signon",
#     "node_2": "signon",
#     "edge": "Signon is a class representing user authentication information, and signon is a variable name used in the insertSignon() method to pass a new Signon object."
#   },
#   {
#     "node_1": "DaoTransaction",
#     "node_2": "trans",
#     "edge": "DaoTransaction represents a database transaction and trans is a parameter passed to the methods to initiate the transaction."
#   },
#   {
#     "node_1": "SignonDao",
#     "node_2": "SignonDao",
#     "edge": "SignonDao is an interface representing methods for working with Signon objects."
#   },
#   {
#     "node_1": "com.ibatis",
#     "node_2": "jpetstore",
#     "edge": "com.ibatis and jpetstore are packages used to organize classes and interfaces within a Java project, and this line indicates that the SignonDao class is located in the com.ibatis.jpetstore package."
#   },
#   {
#     "node_1": "BaseCacheDao",
#     "node_2": "cache",
#     "edge": "BaseCacheDao is a superclass for cache-aware DAOs, and 'cache' is a subpackage within the com.ibatis.jpetstore package."
#   },
#   {
#     "node_1": "List",
#     "node_2": "getProductList(DaoTransaction trans)",
#     "edge": "List is a collection of elements, and getProductList(DaoTransaction trans) is a method in the class where this code snippet is located."
#   },
#   {
#     "node_1": "List",
#     "node_2": "getProductListByCategory(DaoTransaction trans, String categoryId)",
#     "edge": "List is a collection of elements, and getProductListByCategory(DaoTransaction trans, String categoryId) is a method in the class where this code snippet is located."
#   },
#   {
#     "node_1": "List",
#     "node_2": "getProductListByKeyword(DaoTransaction trans, String keyword)",
#     "edge": "List is a collection of elements, and getProductListByKeyword(DaoTransaction trans, String keyword) is a method in the class where this code snippet is located."
#   },
#   {
#     "node_1": "DaoTransaction",
#     "node_2": "trans",
#     "edge": "DaoTransaction represents a database transaction and 'trans' is a parameter passed to these methods for initiating transactions."
#   }
# ][
#    {
#        "node_1": "BaseCacheDao",
#        "node_2": "DAO",
#        "edge": "BaseCacheDao is an example of how DAO provides a pluggable framework."
#    },
#    {
#        "node_1": "BaseCacheDao",
#        "node_2": "cache",
#        "edge": "BaseCacheDao contains a cache."
#    },
#    {
#        "node_1": "BaseCacheDao",
#        "node_2": "MAX_ITEMS_PER_CHANNEL",
#        "edge": "BaseCacheDao has a constant MAX_ITEMS_PER_CHANNEL."
#    },
#    {
#        "node_1": "BaseCacheDao",
#        "node_2": "CHANNELS",
#        "edge": "BaseCacheDao uses a Map called CHANNELS to store CacheChannels."
#    },
#    {
#        "node_1": "BaseCacheDao",
#        "node_2": "getClass()",
#        "edge": "BaseCacheDao retrieves the appropriate CacheChannel from CHANNELS based on its class."
#    },
#    {
#        "node_1": "CacheChannel",
#        "node_2": "cache",
#        "edge": "Each CacheChannel contains a Map called cache to store objects."
#    },
#    {
#        "node_1": "CacheChannel",
#        "node_2": "keys",
#        "edge": "Each CacheChannel also contains a List called keys to keep track of the keys used to access objects from its cache."
#    }
# ][
#    {
#        "node_1": "CacheChannel",
#        "node_2": "cache",
#        "edge": "contains a map called cache which stores data"
#    },
#    {
#        "node_1": "CacheChannel",
#        "node_2": "keys",
#        "edge": "maintains a list of keys associated with the stored data"
#    },
#    {
#        "node_1": "PetStoreCacheDao",
#        "node_2": "ItemDao",
#        "edge": "extends BaseCacheDao and provides implementation for item related operations through ItemMapDao"
#    },
#    {
#        "node_1": "PetStoreCacheDao",
#        "node_2": "ProductDao",
#        "edge": "extends BaseCacheDao and provides implementation for product related operations through ProductMapDao"
#    },
#    {
#        "node_1": "PetStoreCacheDao",
#        "node_2": "CategoryDao",
#        "edge": "extends BaseCacheDao and provides implementation for category related operations through CategoryMapDao"
#    },
#    {
#        "node_1": "PetStoreCacheDao",
#        "node_2": "InventoryDao",
#        "edge": "extends BaseCacheDao and provides implementation for inventory related operations through InventoryMapDao"
#    },
#    {
#        "node_1": "com.ibatis.jpetstore.persistence.dao.cache",
#        "node_2": "BaseCacheDao",
#        "edge": "is a parent class which provides basic cache functionality for DAOs"
#    }
# ][
#    {
#        "node_1": "getProductList",
#        "node_2": "productDao.getProductList",
#        "edge": "belongs to method 'getProductList' which calls 'productDao.getProductList'"
#    },
#    {
#        "node_1": "getProductList",
#        "node_2": "list",
#        "edge": "returns a list of products called 'list'"
#    },
#    {
#        "node_1": "list",
#        "node_2": "productDao",
#        "edge": "stored in variable 'list' after being retrieved from 'productDao'"
#    },
#    {
#        "node_1": "getProductListByCategory",
#        "node_2": "categoryId",
#        "edge": "takes a category ID as parameter"
#    },
#    {
#        "node_1": "getProductListByCategory",
#        "node_2": "productDao.getProductListByCategory",
#        "edge": "belongs to method 'getProductListByCategory' which calls 'productDao.getProductListByCategory'"
#    },
#    {
#        "node_1": "getProductListByCategory",
#        "node_2": "list",
#        "edge": "returns a list of products called 'list'"
#    },
#    {
#        "node_1": "getItem",
#        "node_2": "itemId",
#        "edge": "takes an item ID as parameter"
#    },
#    {
#        "node_1": "getItem",
#        "node_2": "itemDao.getItem",
#        "edge": "belongs to method 'getItem' which calls 'itemDao.getItem'"
#    },
#    {
#        "node_1": "getItem",
#        "node_2": "Item",
#        "edge": "returns an Item object"
#    },
#    {
#        "node_1": "getItemList",
#        "node_2": "itemDao.getItemList",
#        "edge": "belongs to method 'getItemList' which calls 'itemDao.getItemList'"
#    },
#    {
#        "node_1": "getItemList",
#        "node_2": "list",
#        "edge": "returns a list of Items called 'list'"
#    },
#    {
#        "node_1": "getItemListByProduct",
#        "node_2": "productId",
#        "edge": "takes a product ID as parameter"
#    },
#    {
#        "node_1": "getItemListByProduct",
#        "node_2": "itemDao.getItemListByProduct",
#        "edge": "belongs to method 'getItemListByProduct' which calls 'itemDao.getItemListByProduct'"
#    },
#    {
#        "node_1": "getItemListByProduct",
#        "node_2": "list",
#        "edge": "returns a list of Items called 'list'"
#    }
# ][
#   {
#     "node_1": "updateInventoryQuantity",
#     "node_2": "DaoTransaction",
#     "edge": "is called with a DaoTransaction object"
#   },
#   {
#     "node_1": "itemId",
#     "node_2": "inventoryDao",
#     "edge": "is used in the invocation of inventoryDao.updateInventoryQuantity(trans, itemId, quantity)"
#   },
#   {
#     "node_1": "Category",
# ...
#    },
#    {
#        "node_1": "CartForm",
#        "node_2": "com.ibatis.jpetstore.presentation",
#        "edge": "is a part of presentation layer of JPetStore application."
#    },
#    {
#        "node_1": "CartForm",
#        "node_2": "com.ibatis.jpetstore",
#        "edge": "belongs to the com.ibatis.jpetstore package which contains classes for JPetStore project."
#    },
#    {
#        "node_1": "CartItem",
#        "node_2": "com.ibatis.jpetstore.domain",
#        "edge": "belongs to the domain layer which represents the data objects in the JPetStore project."
#    },
#    {
#        "node_1": "CartItem",
#        "node_2": "com.ibatis.jpetstore",
#        "edge": "belongs to the com.ibatis.jpetstore package which contains classes for JPetStore project."
#    },
#    {
#        "node_1": "CartItem",
#        "node_2": "Item",
#        "edge": "is associated with Item class which represents an item in the store."
#    },
#    {
#        "node_1": "com.ibatis.jpetstore",
#        "node_2": "WEB-INF",
#        "edge": "contains web application configuration and resources for JPetStore project."
#    },
#    {
#        "node_1": "com.ibatis.jpetstore",
#        "node_2": "src",
#        "edge": "contains Java source files for the JPetStore project."
#    },
#    {
#        "node_1": "WEB-INF",
#        "node_2": "classes",
#        "edge": "contains compiled class files for JPetStore project."
#    },
#    {
#        "node_1": "UpdateCartQuantitiesAction",
#        "node_2": "request.getParameter(itemId)",
#        "edge": "accesses the request parameter 'itemId' to obtain the new quantity value."
#    },
#    {
#        "node_1": "CartForm",
#        "node_2": "getCart()",
#        "edge": "returns a Cart object which contains the cart items for the user."
#    },
#    {
#        "node_1": "CartForm",
#        "node_2": "setAccount(account)",
#        "edge": "sets the account information obtained from the login process."
#    },
#    {
#        "node_1": "CartForm",
#        "node_2": "setPassword(null)",
#        "edge": "resets the password to null after successful login."
#    },
#    {
#        "node_1": "CartItem",
#        "node_2": "getItem()",
#        "edge": "returns the Item object associated with this CartItem."
#    },
#    {
#        "node_1": "com.ibatis.jpetstore.domain",
#        "node_2": "com.ibatis.jpetstore",
#        "edge": "contains domain classes for JPetStore project which represent the data entities in the store."
#    },
#    {
#        "node_1": "HttpServletRequest",
#        "node_2": "request.getParameter(itemId)",
#        "edge": "provides access to request parameters in a web application using Struts framework."
#    },
#    {
#        "node_1": "com.ibatis.jpetstore",
#        "node_2": "src",
#        "edge": "contains the Java source files for classes and resources related to JPetStore project."
#    },
#    {
#        "node_1": "Item",
#        "node_2": "com.ibatis.jpetstore.domain",
#        "edge": "represents an item in the store which includes information such as product details, price, and quantity."
#    },
#    {
#        "node_1": "HttpServletResponse",
#        "node_2": "response",
#        "edge": "provides access to the HTTP response for a web application using Struts framework."
#    }
# ][
#    {
#        "node_1": "ViewCategoryAction",
#        "node_2": "CategoryDao",
#        "edge": "ViewCategoryAction uses CategoryDao to retrieve Category object for specified Category ID"
#    },
#    {
#        "node_1": "ViewCategoryAction",
#        "node_2": "CategoryForm",
#        "edge": "ViewCategoryAction interacts with CategoryForm to get and set category information"
#    },
#    {
#        "node_1": "ViewCategoryAction",
#        "node_2": "Mapping",
#        "edge": "ViewCategoryAction is mapped to a specific ActionMapping"
#    },
#    {
#        "node_1": "ViewCategoryAction",
#        "node_2": "HttpServletRequest",
#        "edge": "ViewCategoryAction receives information through HttpServletRequest object"
#    },
#    {
#        "node_1": "ViewCategoryAction",
#        "node_2": "HttpServletResponse",
#        "edge": "ViewCategoryAction sends response to client using HttpServletResponse object"
#    },
#    {
#        "node_1": "ViewItemAction",
#        "node_2": "ProductDao",
#        "edge": "ViewItemAction uses ProductDao to retrieve product list for specified Category ID"
#    },
#    {
#        "node_1": "ViewItemAction",
#        "node_2": "CategoryForm",
#        "edge": "ViewItemAction interacts with CategoryForm to get and set category information"
#    },
#    {
#        "node_1": "ViewItemAction",
#        "node_2": "Mapping",
#        "edge": "ViewItemAction is mapped to a specific ActionMapping"
#    },
#    {
#        "node_1": "ViewItemAction",
#        "node_2": "HttpServletRequest",
#        "edge": "ViewItemAction receives information through HttpServletRequest object"
#    },
#    {
#        "node_1": "ViewItemAction",
#        "node_2": "HttpServletResponse",
#        "edge": "ViewItemAction sends response to client using HttpServletResponse object"
#    }
# ][
#    {
#       "node_1": "ViewItemAction",
#       "node_2": "BaseAction",
#       "edge": "is a type of Action in the context."
#    },
#    {
#       "node_1": "ViewItemAction",
#       "node_2": "Mapping",
#       "edge": "interacts with to determine the forward to take."
#    },
#    {
#       "node_1": "ViewItemAction",
#       "node_2": "Form",
#       "edge": "manipulates and uses this object for storing user data."
#    },
#    {
#       "node_1": "ViewItemAction",
#       "node_2": "HttpServletRequest",
#       "edge": "is used to access request attributes and parameters sent by client."
#    },
#    {
#       "node_1": "ViewItemAction",
#       "node_2": "HttpServletResponse",
#       "edge": "is used to send HTTP responses back to the client."
#    },
#    {
#       "node_1": "DaoTransaction",
#       "node_2": "ItemDao",
#       "edge": "is used to retrieve Item object by its ID."
#    },
#    {
#       "node_1": "DaoTransaction",
#       "node_2": "ProductDao",
#       "edge": "is used to retrieve Product object by Item's product ID."
#    },
#    {
#       "node_1": "ItemForm",
#       "node_2": "ViewItemAction",
#       "edge": "is an argument passed to the ViewItemAction."
#    },
#    {
#       "node_1": "ItemForm",
#       "node_2": "Product",
#       "edge": "represents a product associated with an Item."
#    },
#    {
#       "node_1": "ItemForm",
#       "node_2": "Item",
#       "edge": "is used to store and retrieve Item data through the ViewItemAction."
#    },
#    {
#       "node_1": "ViewOrderAction",
#       "node_2": "BaseAction",
#       "edge": "is a type of Action in the context."
#    },
#    {
#       "node_1": "ViewOrderAction",
#       "node_2": "Mapping",
#       "edge": "interacts with to determine the forward to take."
#    },
#    {
#       "node_1": "ViewOrderAction",
#       "node_2": "Form",
#       "edge": "manipulates and uses this object for storing user data."
#    },
#    {
#       "node_1": "ViewOrderAction",
#       "node_2": "HttpServletRequest",
#       "edge": "is used to access request attributes and parameters sent by client."
#    },
#    {
#       "node_1": "ViewOrderAction",
#       "node_2": "HttpServletResponse",
#       "edge": "is used to send HTTP responses back to the client."
#    },
#    {
#       "node_1": "DaoTransaction",
#       "node_2": "ItemDao",
#       "edge": "is used to retrieve Item object by its ID."
#    },
#    {
#       "node_1": "DaoTransaction",
#       "node_2": "OrderDao",
#       "edge": "is used to retrieve Order object by an unknown identifier in the context."
#    }
# ]Here's an example of how the extracted ontology might look like:
#
# ```json
# [
#   {
#     "node_1": "ViewProductAction",
#     "node_2": "com.ibatis.jpetstore.presentation.action.ViewProductAction",
#     "edge": "is a subclass of"
#   },
#   {
#     "node_1": "BaseAction",
#        "node_2": "org.apache.struts.action.BaseAction",
#     "edge": "is a subclass of"
#   },
#   {
#     "node_1": "ProductForm",
#     "node_2": "com.ibatis.jpetstore.presentation.form.ProductForm",
#     "edge": "is a subclass of"
#   },
#   {
#     "node_1": "ActionForm",
#     "node_2": "org.apache.struts.action.ActionForm",
#     "edge": "is a subclass of"
#   },
#   {
#     "node_1": "ViewProductAction",
#     "node_2": "mapping",
#     "edge": "has a member variable called"
#   },
#   {
#     "node_1": "com.ibatis.jpetstore.presentation.action.ViewProductAction",
#     "node_2": "WEB-INF",
#     "edge": "is located in"
#   },
#   {
#     "node_1": "WebappRootLIBRARY",
#     "node_2": "com/ibatis/jpetstore",
#     "edge": "is contained within"
#   },
#   {
#     "node_1": "ViewProductAction",
#     "node_2": "doPerform",
#     "edge": "has a method called"
#   },
#   {
#     "node_1": "Request",
#     "node_2": "request",
#     "edge": "is passed as an argument to"
#   },
#   {
#     "node_1": "Mapping",
#     "node_2": "mapping",
#     "edge": "is passed as an argument to"
#   },
#   {
#     "node_1": "com.ibatis.jpetstore.presentation.action.ViewProductAction",
#     "node_2": "orderId",
#     "edge": "has a member variable called"
#   },
#   {
#     "node_1": "HttpServletRequest",
#     "node_2": "request",
#     "edge": "is obtained from"
#   },
#   {
#     "node_1": "Integer",
#     "node_2": "orderId",
#     "edge": "is converted to"
#   },
#   {
#     "node_1": "OrderDao",
#     "node_2": "orderDao",
#     "edge": "has a member variable called"
#   },
#   {
#     "node_1": "DaoManager",
#     "node_2": "daoManager",
#     "edge": "has a member variable called"
#   },
#   {
#     "node_1": "Order",
#     "node_2": "order",
#     "edge": "is obtained from"
#   },
#   {
#     "node_1": "OrderDao",
#     "node_2": "getOrder",
#     "edge": "has a method called"
#   },
#   {
#     "node_1": "DaoTransaction",
#     "node_2": "trans",
#     "edge": "is obtained from"
#   },
#   {
#     "node_1": "List",
#     "node_2": "list",
#     "edge": "is obtained from"
#   },
#   {
#     "node_1": "LineItemDao",
#     "node_2": "lineItemDao",
#     "edge": "has a member variable called"
#   },
#   {
#     "node_1": "orderId",
#     "node_2": "list",
#     "edge": "is used to filter"
#   },
# ]
# ```
#
# The output shows how the different classes and methods are related to each other, highlighting the structure of the code. The format is easy to interpret for humans but also convenient for machine learning algorithms that can use this information to better understand the software system being analyzed.
#
# ERROR ### Here is the buggy response:  Here's an example of how the extracted ontology might look like:
#
# ```json
# [
#   {
#     "node_1": "ViewProductAction",
#     "node_2": "com.ibatis.jpetstore.presentation.action.ViewProductAction",
#     "edge": "is a subclass of"
#   },
#   {
#     "node_1": "BaseAction",
#        "node_2": "org.apache.struts.action.BaseAction",
#     "edge": "is a subclass of"
#   },
#   {
#     "node_1": "ProductForm",
#     "node_2": "com.ibatis.jpetstore.presentation.form.ProductForm",
#     "edge": "is a subclass of"
#   },
#   {
#     "node_1": "ActionForm",
#     "node_2": "org.apache.struts.action.ActionForm",
#     "edge": "is a subclass of"
#   },
#   {
#     "node_1": "ViewProductAction",
#     "node_2": "mapping",
#     "edge": "has a member variable called"
#   },
#   {
#     "node_1": "com.ibatis.jpetstore.presentation.action.ViewProductAction",
#     "node_2": "WEB-INF",
#     "edge": "is located in"
#   },
#   {
#     "node_1": "WebappRootLIBRARY",
#     "node_2": "com/ibatis/jpetstore",
#     "edge": "is contained within"
#   },
#   {
#     "node_1": "ViewProductAction",
#     "node_2": "doPerform",
#     "edge": "has a method called"
#   },
#   {
#     "node_1": "Request",
#     "node_2": "request",
#     "edge": "is passed as an argument to"
#   },
#   {
#     "node_1": "Mapping",
#     "node_2": "mapping",
#     "edge": "is passed as an argument to"
#   },
#   {
#     "node_1": "com.ibatis.jpetstore.presentation.action.ViewProductAction",
#     "node_2": "orderId",
#     "edge": "has a member variable called"
#   },
#   {
#     "node_1": "HttpServletRequest",
#     "node_2": "request",
#     "edge": "is obtained from"
#   },
#   {
#     "node_1": "Integer",
#     "node_2": "orderId",
#     "edge": "is converted to"
#   },
#   {
#     "node_1": "OrderDao",
#     "node_2": "orderDao",
#     "edge": "has a member variable called"
#   },
#   {
#     "node_1": "DaoManager",
#     "node_2": "daoManager",
#     "edge": "has a member variable called"
#   },
#   {
#     "node_1": "Order",
#     "node_2": "order",
#     "edge": "is obtained from"
#   },
#   {
#     "node_1": "OrderDao",
#     "node_2": "getOrder",
#     "edge": "has a method called"
#   },
#   {
#     "node_1": "DaoTransaction",
#     "node_2": "trans",
#     "edge": "is obtained from"
#   },
#   {
#     "node_1": "List",
#     "node_2": "list",
#     "edge": "is obtained from"
#   },
#   {
#     "node_1": "LineItemDao",
#     "node_2": "lineItemDao",
#     "edge": "has a member variable called"
#   },
#   {
#     "node_1": "orderId",
#     "node_2": "list",
#     "edge": "is used to filter"
#   },
# ]
# ```
#
# The output shows how the different classes and methods are related to each other, highlighting the structure of the code. The format is easy to interpret for humans but also convenient for machine learning algorithms that can use this information to better understand the software system being analyzed.
#
#
# [
#    {
#       "node_1": "ProductForm",
#       "node_2": "product",
#       "edge": "ProductForm is used to interact with a specific product, and the product object (of type Product) is retrieved using productDao.getProduct(trans, prodForm.getProductId())."
#    },
#    {
#       "node_1": "itemDao",
#       "node_2": "itemList",
#       "edge": "The itemDao is used to retrieve a list of items (of type List) for the specified product using itemDao.getItemListByProduct(trans, prodForm.getProductId())."
#    },
#    {
#       "node_1": "request",
#       "node_2": "message",
#       "edge": "If the product cannot be found, an error message (of type String) is set as an attribute of the request object using request.setAttribute(\"message\", \"Error viewing Product. Could not find Product for Product ID specified.\")."
#    },
#    {
#       "node_1": "forwardAction",
#       "node_2": "success",
#       "edge": "Depending on whether the product was found or not, a different forward action is set using return mapping.findForward(\"failure\") and return mapping.findForward(\"success\")."
#    },
#    {
#       "node_1": "AccountForm",
#       "node_2": "username",
#       "edge": "The AccountForm class is used to handle forms related to user accounts, and the username field (of type String) is accessed using username."
#    },
#    {
#       "node_1": "AccountForm",
#       "node_2": "password",
#       "edge": "The password field (of type String) is also accessed using password."
#    },
#    {
#       "node_1": "AccountForm",
#       "node_2": "repeatedPassword",
#       "edge": "The repeatedPassword field (also of type String) may be used to verify the user's password."
#    },
#    {
#       "node_1": "AccountForm",
#       "node_2": "languages",
#       "edge": "The languages field (of type List) contains a list of available languages, which can be accessed using languages."
#    },
#    {
#       "node_1": "AccountForm",
#       "node_2": "categories",
#       "edge": "Similarly, the categories field (also of type List) may contain a list of available categories."
#    },
#    {
#       "node_1": "AccountForm",
#       "node_2": "validate",
#       "edge": "The validate field (of type String) is used to identify which form validation action should be taken (either \"editAccount\" or \"newAccount\")."
#    },
#    {
#       "node_1": "AccountForm",
#       "node_2": "myList",
#       "edge": "The myList field (of type List) may contain some arbitrary list of values."
#    }
# ][
#   {
#     "node_1": "AccountForm",
#     "node_2": "account",
#     "edge": "Belongs to AccountForm and is a property of it."
#   },
#   {
#     "node_1": "username",
#     "node_2": "AccountForm.getUsername()",
#     "edge": "Can be accessed using the getter method of AccountForm."
#   },
#   {
#     "node_1": "setUsername",
#     "node_2": "AccountForm",
#     "edge": "Used to set the value of username property of AccountForm."
#   },
#   {
#     "node_1": "myList",
#     "node_2": "AccountForm.getMyList()",
#     "edge": "Can be accessed using the getter method of AccountForm."
#   },
#   {
#     "node_1": "setMyList",
#     "node_2": "AccountForm",
#     "edge": "Used to set the value of myList property of AccountForm."
#   },
#   {
#     "node_1": "forwardAction",
#     "node_2": "AccountForm",
#     "edge

# %% [markdown]
# Use Existing Knowledge Graph
# =====================

# %%
## To regenerate the graph with LLM, set this to True
regenerate = False


if regenerate:
    concepts_list = df2Graph(df, model='zephyr:latest')
    dfg1 = graph2Df(concepts_list)
    if not os.path.exists(outputdirectory):
        os.makedirs(outputdirectory)
    
    dfg1.to_csv(outputdirectory/"graph.csv", sep="|", index=False)
    df.to_csv(outputdirectory/"chunks.csv", sep="|", index=False)
else:
    dfg1 = pd.read_csv(outputdirectory/"graph.csv", sep="|", on_bad_lines='skip')

dfg1.replace("", np.nan, inplace=True)
dfg1.dropna(subset=["node_1", "node_2", 'edge'], inplace=True)
dfg1['count'] = 4 
## Increasing the weight of the relation to 4. 
## We will assign the weight of 1 when later the contextual proximity will be calculated.  
print(dfg1.shape)
dfg1.head()
dfg1.tail()
# Out:
# (916, 9)
#             node_1                       node_2  \
# 918      languages   accountform.getlanguages()
# 919   setlanguages                  accountform
# 920     categories  accountform.getcategories()
# 921  setcategories                  accountform
# 922       validate    accountform.getvalidate()
#
#                                                   edge  \
# 918  Can be accessed using the getter method of Acc...
# 919  Used to set the value of languages property of...
# 920  Can be accessed using the getter method of Acc...
# 921  Used to set the value of categories property o...
# 922  Can be accessed using the getter method of Acc...
#
#                              chunk_id node_3 node_4 edge_1 edge_2  count
# 918  8be17bec52764f38828e8bdf8d21c85a    NaN    NaN    NaN    NaN      4
# 919  8be17bec52764f38828e8bdf8d21c85a    NaN    NaN    NaN    NaN      4
# 920  8be17bec52764f38828e8bdf8d21c85a    NaN    NaN    NaN    NaN      4
# 921  8be17bec52764f38828e8bdf8d21c85a    NaN    NaN    NaN    NaN      4
# 922  8be17bec52764f38828e8bdf8d21c85a    NaN    NaN    NaN    NaN      4

# %% [markdown]
# ## Calculating contextual proximity

# %%
def contextual_proximity(df: pd.DataFrame) -> pd.DataFrame:
    ## Melt the dataframe into a list of nodes
    dfg_long = pd.melt(
        df, id_vars=["chunk_id"], value_vars=["node_1", "node_2"], value_name="node"
    )
    dfg_long.drop(columns=["variable"], inplace=True)
    # Self join with chunk id as the key will create a link between terms occuring in the same text chunk.
    dfg_wide = pd.merge(dfg_long, dfg_long, on="chunk_id", suffixes=("_1", "_2"))
    # drop self loops
    self_loops_drop = dfg_wide[dfg_wide["node_1"] == dfg_wide["node_2"]].index
    dfg2 = dfg_wide.drop(index=self_loops_drop).reset_index(drop=True)
    ## Group and count edges.
    dfg2 = (
        dfg2.groupby(["node_1", "node_2"])
        .agg({"chunk_id": [",".join, "count"]})
        .reset_index()
    )
    dfg2.columns = ["node_1", "node_2", "chunk_id", "count"]
    dfg2.replace("", np.nan, inplace=True)
    dfg2.dropna(subset=["node_1", "node_2"], inplace=True)
    # Drop edges with 1 count
    dfg2 = dfg2[dfg2["count"] != 1]
    dfg2["edge"] = "contextual proximity"
    return dfg2


dfg2 = contextual_proximity(dfg1)

# %% [markdown]
# ### Merge both the dataframes

# %%
dfg = pd.concat([dfg1, dfg2], axis=0)
dfg = (
    dfg.groupby(["node_1", "node_2"])
    .agg({"chunk_id": ",".join, "edge": ','.join, 'count': 'sum'})
    .reset_index()
)
dfg
# Out:
#                                               node_1  \
# 0                                'com.ibatis.db.dao'
# 1                                'com.ibatis.db.dao'
# 2                                'com.ibatis.db.dao'
# 3                                'com.ibatis.db.dao'
# 4     'com.ibatis.db.dao.impl.abstractbasesqlmapper'
# ...                                              ...
# 7254                                             zip
# 7255                                             zip
# 7256                                             zip
# 7257                                             zip
# 7258                                             zip
#
#                                           node_2  \
# 0                                     basemapdao
# 1                                    categorydao
# 2     getnextid method of class 'categorymapdao'
# 3                                 sequence class
# 4                                     basemapdao
# ...                                          ...
# 7254                                      setzip
# 7255                                       state
# 7256                                      status
# 7257                                      userid
# 7258                                    validate
#
#                                                chunk_id  \
# 0     727c8467fbb54c1782931a63326cdb50,727c8467fbb54...
# 1     727c8467fbb54c1782931a63326cdb50,727c8467fbb54...
# 2     727c8467fbb54c1782931a63326cdb50,727c8467fbb54...
# 3     727c8467fbb54c1782931a63326cdb50,727c8467fbb54...
# 4     727c8467fbb54c1782931a63326cdb50,727c8467fbb54...
# ...                                                 ...
# 7254                   1d1530ecebdc4c48bf829539106d365d
# 7255  1d1530ecebdc4c48bf829539106d365d,3ebda43775704...
# 7256  3ebda43775704e379e4792a1639f8e14,28c4cf26aeff4...
# 7257  28c4cf26aeff4a75b7dff80bdb6f42ad,24481914343a4...
# 7258  3ebda43775704e379e4792a1639f8e14,3ebda43775704...
#
#                                                    edge  count
# 0                                  contextual proximity      2
# 1                                  contextual proximity      4
# 2                                  contextual proximity      3
# 3                                  contextual proximity      2
# 4                                  contextual proximity      2
# ...                                                 ...    ...
# 7254  The Cart class has a member variable named zip...      4
# 7255                               contextual proximity      4
# 7256                               contextual proximity      3
# 7257                               contextual proximity      2
# 7258                               contextual proximity      2
#
# [7259 rows x 5 columns]

# %% [markdown]
# ## Calculate the NetworkX Graph

# %%
nodes = pd.concat([dfg['node_1'], dfg['node_2']], axis=0).unique()
nodes.shape
# Out:
# (552,)

# %%
import networkx as nx
G = nx.Graph()

## Add nodes to the graph
for node in nodes:
    G.add_node(
        str(node)
    )

## Add edges to the graph
for index, row in dfg.iterrows():
    G.add_edge(
        str(row["node_1"]),
        str(row["node_2"]),
        title=row["edge"],
        weight=row['count']/4
    )

# %% [markdown]
# ### Calculate communities for coloring the nodes

# %%
communities_generator = nx.community.girvan_newman(G)
#communities_generator = nx.community.louvain_communities(G)
top_level_communities = next(communities_generator)
next_level_communities = next(communities_generator)
communities = sorted(map(sorted, next_level_communities))
print("Number of Communities = ", len(communities))
print(communities)
# Out:
# Number of Communities =  5
# [["'com.ibatis.db.dao'", "'com.ibatis.db.dao.impl.abstractbasesqlmapper'", "'com.ibatis.db.sqlmap.client.sqlmapclient'", 'accountdao', 'accountform', 'accountform.getpassword()', 'accountform.getusername()', 'acctform', 'acctform.getaccount().getfavouritecategoryid()', 'action', 'actionerrors errors', 'actionform', 'actionmapping', 'actionmapping mapping', 'actionservlet', 'actionsupport', 'additemtocartaction', 'american express', 'attribute1', 'attribute2', 'attribute3', 'attribute4', 'attribute5', 'baseaction', 'baseaction.daomanager', 'basecachedao', 'baseform', 'basemapdao', 'boolean', 'cache', 'cachechannel', 'cacheing', 'card_type_list', 'cartform', 'cartform.getcart().additem(item)', 'cartform.getcart().containsitemid(cartform.getworkingitemid())', 'cartform.getcart().incrementquantitybyitemid(cartform.getworkingitemid())', 'cartform.getworkingitemid()', 'cartitem', 'cartitems', 'categories', 'category', 'categorydao', 'categoryform', 'categoryid', 'categorylist', 'categorymapdao', 'channel', 'channels', 'classes', 'collection', 'com', 'com.ibatis', 'com.ibatis.db.', 'com.ibatis.db.dao', 'com.ibatis.db.dao.', 'com.ibatis.db.dao.basedao', 'com.ibatis.db.dao.dao', 'com.ibatis.db.dao.daotransaction', 'com.ibatis.db.sqlmap', 'com.ibatis.db.sqlmap.', 'com.ibatis.db.sqlmap.client', 'com.ibatis.db.sqlmap.client.sqlmapclient', 'com.ibatis.db.sqlmap.sqlmapclient', 'com.ibatis.db.sqlmap.sqlmapclientcallback', 'com.ibatis.db.transaction', 'com.ibatis.jpetstore', 'com.ibatis.jpetstore.', 'com.ibatis.jpetstore.domain', 'com.ibatis.jpetstore.domain.', 'com.ibatis.jpetstore.domain.account', 'com.ibatis.jpetstore.domain.accountform', 'com.ibatis.jpetstore.domain.categoryid', 'com.ibatis.jpetstore.domain.item', 'com.ibatis.jpetstore.domain.order', 'com.ibatis.jpetstore.domain.product', 'com.ibatis.jpetstore.domain.productcategory', 'com.ibatis.jpetstore.persistence.', 'com.ibatis.jpetstore.persistence.dao', 'com.ibatis.jpetstore.persistence.dao.', 'com.ibatis.jpetstore.persistence.dao.cache', 'com.ibatis.jpetstore.persistence.dao.daoexception', 'com.ibatis.jpetstore.persistence.dao.daotransaction', 'com.ibatis.jpetstore.persistence.dao.item', 'com.ibatis.jpetstore.persistence.dao.itemdao', 'com.ibatis.jpetstore.persistence.dao.lineitemdao', 'com.ibatis.jpetstore.persistence.dao.map', 'com.ibatis.jpetstore.persistence.dao.map.basemapdao', 'com.ibatis.jpetstore.persistence.dao.map.itemdao', 'com.ibatis.jpetstore.persistence.dao.map.itemmapdao', 'com.ibatis.jpetstore.persistence.dao.map.ordermapdao', 'com.ibatis.jpetstore.persistence.dao.orderdao', 'com.ibatis.jpetstore.presentation', 'com.ibatis.jpetstore.presentation.', 'com.ibatis.jpetstore.presentation.action', 'com.ibatis.jpetstore.presentation.action.', 'com.ibatis.jpetstore.presentation.action.baseaction', 'com.ibatis.jpetstore.presentation.action.donothingaction', 'com.ibatis.jpetstore.presentation.action.editaccountaction', 'com.ibatis.jpetstore.presentation.action.removeitemfromcartaction', 'com.ibatis.jpetstore.presentation.action.searchproductsaction', 'com.ibatis.jpetstore.presentation.form', 'com.ibatis.jpetstore.presentation.form.accountform', 'com.ibatis.jpetstore.presentation.form.cartform', 'commit', 'confirmed', 'conn', 'connection', 'dao', 'dao.cache', 'daoexception', 'daomanager', 'daomanager.configure(resources.getresourceasstream("properties/dao.xml"))', 'daomanager.getdao("account")', 'daomanager.getdao("category")', 'daomanager.getdao("inventory")', 'daomanager.getdao("item")', 'daomanager.getdao("lineitem")', 'daomanager.getdao("order")', 'daomanager.getdao("product")', 'daomanager.getdao("signon")', 'daomanager.getinstance()', 'daotransaction', 'description', 'domain', 'donothingaction', 'doperform', 'editaccountaction', 'emptyform', 'errors', 'executequeryforlist', 'executequeryforobject', 'executesql', 'executeupdate', 'findforward', 'form', 'forwardaction', 'getattribute', 'getattribute1', 'getattribute2', 'getattribute3', 'getattribute4', 'getattribute5', 'g ...

# %% [markdown]
# ### Identify services

# %%
## This function uses the helpers/prompt function to extract concepts from text
from helpers.df_helpers import df2Topic
from helpers.df_helpers import topics2Df
import re

def clean_list(my_list) -> list:
    cleaned_list = [re.sub(r'[^A-Za-z0-9]+', ' ', ' '.join(item.strip("'") for item in element)) for element in my_list]
    return cleaned_list
    
topics = clean_list(communities)
#print(topics)
df_topics = pd.DataFrame(topics)
df_topics.rename(columns={0: 'text'}, inplace=True)
#df_topics.head()

topic_list = df2Topic(df_topics, model='zephyr:latest')

#dfg1 = graph2Df(concepts_list1)

#print("done")



#topic_list = df2Topic(df_communites, model='zephyr:latest')
#topics = topics2Df(topic_list)

# %%
#Identify services 

#print(len(df))
# creates a concept list graph from the dataframe feed in and uses the zephyr model to do it. 
    concepts_list = df2Graph(df, model='zephyr:latest')

    dfg1 = graph2Df(concepts_list)
    if not os.path.exists(outputdirectory):
        os.makedirs(outputdirectory)


# take the communities from above. 
        
topics = classify_topic_groups(communities)
#This is broken again....
print(topics)

# %% [markdown]
# ### Create a dataframe for community colors

# %%
import seaborn as sns
palette = "hls"

## Now add these colors to communities and make another dataframe
def colors2Community(communities) -> pd.DataFrame:
    ## Define a color palette
    p = sns.color_palette(palette, len(communities)).as_hex()
    random.shuffle(p)
    rows = []
    group = 0
    for community in communities:
        color = p.pop()
        group += 1
        for node in community:
            rows += [{"node": node, "color": color, "group": group}]
    df_colors = pd.DataFrame(rows)
    return df_colors


colors = colors2Community(communities)
colors
# Out:
#                                                node    color  group
# 0                               'com.ibatis.db.dao'  #5f57db      1
# 1    'com.ibatis.db.dao.impl.abstractbasesqlmapper'  #5f57db      1
# 2        'com.ibatis.db.sqlmap.client.sqlmapclient'  #5f57db      1
# 3                                        accountdao  #5f57db      1
# 4                                       accountform  #5f57db      1
# ..                                              ...      ...    ...
# 366                               setshiptolastname  #db57d3      6
# 367                                   settotalprice  #db57d3      6
# 368                                 shiptofirstname  #db57d3      6
# 369                                  shiptolastname  #db57d3      6
# 370                                      totalprice  #db57d3      6
#
# [371 rows x 3 columns]

# %% [markdown]
# ### Add colors to the graph

# %%
for index, row in colors.iterrows():
    G.nodes[row['node']]['group'] = row['group']
    G.nodes[row['node']]['color'] = row['color']
    G.nodes[row['node']]['size'] = G.degree[row['node']]

# %%
from pyvis.network import Network

#graph_output_directory = "./docs/index.html"
graph_output_file = Path(f"{out_dir}.html")

graph_output_directory = Path(f"./data_output/{out_dir}/{graph_output_file}")
print(graph_output_directory)

net = Network(
    notebook=False,
    # bgcolor="#1a1a1a",
    cdn_resources="remote",
    height="900px",
    width="100%",
    select_menu=True,
    # font_color="#cccccc",
    filter_menu=False,
)

net.from_nx(G)
# net.repulsion(node_distance=150, spring_length=400)
net.force_atlas_2based(central_gravity=0.015, gravity=-31)
# net.barnes_hut(gravity=-18100, central_gravity=5.05, spring_length=380)
net.show_buttons(filter_=["physics"])

#net.show(graph_output_directory, notebook=False)
# Out:
# data_output/logjpetstore/logjpetstore.html

# %%
from pyvis.network import Network

graph_output_directory = "./docs/index.html"

net = Network(
    notebook=False,
    # bgcolor="#1a1a1a",
    cdn_resources="remote",
    height="900px",
    width="100%",
    select_menu=True,
    # font_color="#cccccc",
    filter_menu=False,
)

net.from_nx(G)
# net.repulsion(node_distance=150, spring_length=400)
net.force_atlas_2based(central_gravity=0.015, gravity=-31)
# net.barnes_hut(gravity=-18100, central_gravity=5.05, spring_length=380)
net.show_buttons(filter_=["physics"])

net.show(graph_output_directory, notebook=False)
# Out:
# ./docs/index.html
